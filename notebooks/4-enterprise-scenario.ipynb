# %% [markdown]
# # Demo 4: Enterprise Scenario - Sales Order Processing
#
# **Semantic Kernel Agent Demo**
# *Enterprise AI Training by REDIVAC Technologies*
#
# ---
#
# ## Overview
#
# This notebook demonstrates a realistic enterprise use case: **Sales Order Processing**.
#
# The agent will:
# - Apply corporate discounts
# - Calculate sales tax
# - Compute profit margins
# - Format monetary values
#
# **Purpose:** Show how agents can orchestrate complex business workflows in production environments.
#
# ---

# %% [markdown]
# ## Setup: Import Dependencies

# %%
import asyncio
import sys
from pathlib import Path

# Add parent directory to path to import modules
parent_dir = Path().resolve().parent
sys.path.insert(0, str(parent_dir))

from utils.kernel_setup import setup_kernel
from agents import demo_enterprise_scenario

# %% [markdown]
# ## Initialize Semantic Kernel
#
# The kernel is initialized with:
# - Azure OpenAI connection
# - 4 plugins: MathPlugin, TextPlugin, BusinessPlugin, DataPlugin

# %%
kernel = await setup_kernel()
# Out:
# ✓ Kernel initialized with 4 plugins
#   - MathPlugin (add, multiply, subtract)
#   - TextPlugin (uppercase, count_words, reverse_text)
#   - BusinessPlugin (calculate_discount, calculate_tax, calculate_profit_margin)
#   - DataPlugin (format_currency, calculate_average, concatenate)

# %% [markdown]
# ## Run Demo: Enterprise Sales Order Processing
#
# **Business Scenario:**
#
# A customer orders a product with:
# - List price: $500
# - Corporate discount: 15%
# - Sales tax: 7% (applied after discount)
# - Our cost: $300
#
# The agent will:
# 1. Calculate discounted price
# 2. Apply sales tax
# 3. Calculate profit margin
# 4. Format all monetary values as currency

# %%
await demo_enterprise_scenario(kernel)
# Out:
# ...
# DEMO 4: ENTERPRISE SCENARIO - SALES ORDER PROCESSING
# ...
# Realistic business scenario demonstrating agent orchestration.
#
# Scenario:
#
#     A customer orders a product with list price of $500.
#     They have a corporate discount of 15%.
#     After discount, add 7% sales tax.
#     Calculate the profit margin if our cost is $300.
#     Format all monetary values as currency.
#
#
# Processing order through agent...
#
#    [BusinessPlugin] Original: $500.0, Discount: 15.0% → Final: $425.0
#    [BusinessPlugin] Price: $425.0, Tax rate: 7.0% → Tax: $29.750000000000004
#    [BusinessPlugin] Cost: $300.0, Price: $425.0 → Margin: 29.41%
#    [DataPlugin] Formatting currency: 425.0 → $425.00
#    [DataPlugin] Formatting currency: 29.75 → $29.75
#    [DataPlugin] Formatting currency: 454.75 → $454.75
# Here are the details of the order:
#
# - **Discounted Price:** $425.00
# - **Sales Tax (7%):** $29.75
# - **Total Price after Tax:** $454.75
# - **Profit Margin Percentage:** 29.41%
#
# ...

# %% [markdown]
# ## Key Takeaways
#
# ✅ **Real-world application** - Agents can handle complex business workflows
# ✅ **Multi-step orchestration** - Automatic coordination of multiple operations
# ✅ **Plugin reusability** - Same plugins used across different scenarios
# ✅ **Production ready** - Can be integrated into enterprise systems
#
# ---
#
# ## Next Steps for Enterprise Implementation
#
# ### Integration Ideas:
# - Connect to CRM systems (Salesforce, Dynamics)
# - Integrate with ERP platforms (SAP, Oracle)
# - Add error handling and retry logic
# - Implement audit logging and monitoring
# - Scale with Azure Functions or containers
#
# ### Advanced Topics:
# - Multi-agent coordination
# - Memory and context management
# - Custom plugin development
# - Performance optimization
# - Security and compliance
#
# ---
#
# ## Course Summary
#
# Congratulations! You've completed all 4 demos:
#
# 1. ✅ [Basic Agent](1-basic-agent.ipynb) - Auto function calling
# 2. ✅ [Reasoning Agent](2-reasoning-agent.ipynb) - Complex reasoning
# 3. ✅ [Agent Comparison](3-agent-comparison.ipynb) - Different instruction styles
# 4. ✅ **Enterprise Scenario** - Real-world application
#
# You're now ready to build production AI agents with Semantic Kernel!
