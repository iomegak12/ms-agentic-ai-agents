# %% [markdown]
# # Demo 1: Basic Agent with Auto Function Calling
#
# **Semantic Kernel Agent Demo**
# *Enterprise AI Training by REDIVAC Technologies*
#
# ---
#
# ## Overview
#
# This notebook demonstrates how agents use function calling to create step-by-step plans to achieve goals. The agent automatically chains functions together in sequence.
#
# **Best for:** Tasks that require a clear sequence of steps.
#
# ---

# %% [markdown]
# ## Setup: Import Dependencies

# %%
import asyncio
import sys
from pathlib import Path

# Add parent directory to path to import modules
parent_dir = Path().resolve().parent
sys.path.insert(0, str(parent_dir))

from utils.kernel_setup import setup_kernel
from agents import demo_basic_agent

# %% [markdown]
# ## Initialize Semantic Kernel
#
# The kernel is initialized with:
# - Azure OpenAI connection
# - 4 plugins: MathPlugin, TextPlugin, BusinessPlugin, DataPlugin

# %%
kernel = await setup_kernel()
# Out:
# ✓ Kernel initialized with 4 plugins
#   - MathPlugin (add, multiply, subtract)
#   - TextPlugin (uppercase, count_words, reverse_text)
#   - BusinessPlugin (calculate_discount, calculate_tax, calculate_profit_margin)
#   - DataPlugin (format_currency, calculate_average, concatenate)

# %% [markdown]
# ## Run Demo: Basic Agent
#
# This demo includes two examples:
#
# ### Example 1: Multi-step Business Calculation
# Calculate the final price with discount and tax.
#
# ### Example 2: Text Processing Chain
# Convert text to uppercase and count words.

# %%
await demo_basic_agent(kernel)
# Out:
# ================================================================================
# DEMO 1: AGENT WITH AUTO FUNCTION CALLING
# ================================================================================
# The Agent uses function calling to create a step-by-step plan to achieve a goal.
# It chains functions together in sequence.
#
# Example 1: Calculate final price after discount and tax
# ------------------------------------------------------------
# Goal: Calculate the final price if an item costs $100, has a 20% discount, and 8% tax rate
#
# Agent is processing...
#
#    [BusinessPlugin] Original: $100.0, Discount: 20.0% → Final: $80.0
#    [BusinessPlugin] Price: $100.0, Tax rate: 8.0% → Tax: $8.0
#    [MathPlugin] Adding 80.0 + 8.0 = 88.0
# The final price of the item, after applying a 20% discount and adding 8% tax, is $88.00.
#
#
# Example 2: Text transformation chain
# ------------------------------------------------------------
# Goal: Take the text 'hello world', convert it to uppercase, then count the words
#
# Agent is processing...
#
#    [TextPlugin] Converting to uppercase: hello world → HELLO WORLD
#    [TextPlugin] Counting words in 'hello world': 2 words
# The text "hello world" converted to uppercase is "HELLO WORLD", and the number of words in the text is 2.

# %% [markdown]
# ## Key Takeaways
#
# ✅ **Agents** automatically orchestrate function calls to solve complex tasks
# ✅ **Function calling** allows the agent to use available plugins
# ✅ **Sequential execution** chains multiple operations together
# ✅ **Plugins** provide reusable capabilities (math, text, business logic)
#
# ---
#
# **Next:** Try the [Reasoning Agent Demo](2-reasoning-agent.ipynb) for more complex scenarios!
