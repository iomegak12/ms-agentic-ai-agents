# %% [markdown]
# # Demo 3: Agent Comparison
#
# **Semantic Kernel Agent Demo**
# *Enterprise AI Training by REDIVAC Technologies*
#
# ---
#
# ## Overview
#
# This notebook demonstrates how different agent instructions affect behavior when solving the same complex task. We'll compare:
#
# 1. **Direct Agent** - Solves problems efficiently and directly
# 2. **Detailed Reasoning Agent** - Breaks down problems and explains reasoning
#
# **Purpose:** Understand how agent instructions guide behavior and output.
#
# ---

# %% [markdown]
# ## Setup: Import Dependencies

# %%
import asyncio
import sys
from pathlib import Path

# Add parent directory to path to import modules
parent_dir = Path().resolve().parent
sys.path.insert(0, str(parent_dir))

from utils.kernel_setup import setup_kernel
from agents import demo_agent_comparison

# %% [markdown]
# ## Initialize Semantic Kernel
#
# The kernel is initialized with:
# - Azure OpenAI connection
# - 4 plugins: MathPlugin, TextPlugin, BusinessPlugin, DataPlugin

# %%
kernel = await setup_kernel()

# %% [markdown]
# ## Run Demo: Agent Comparison
#
# This demo compares two agents with different instructions solving the same task:
#
# **Task:** Calculate the profit margin for a product that costs $80 to make, sells for $120 after a 10% discount, and format the result as a percentage.
#
# ### Approach 1: Direct Agent
# Instruction: *"Use the available functions to solve the problem directly and efficiently."*
#
# ### Approach 2: Detailed Reasoning Agent
# Instruction: *"Break down the problem into steps, explain your reasoning, and use the available functions to compute the answer."*

# %%
await demo_agent_comparison(kernel)

# %% [markdown]
# ## Key Takeaways
#
# ✅ **Instructions matter** - Agent behavior is guided by its instructions
# ✅ **Different approaches** - Same task can be solved in multiple ways
# ✅ **Trade-offs** - Direct approach vs. detailed explanation
# ✅ **Customization** - Tailor agents to specific use cases and audiences
#
# ---
#
# **Next:** Try the [Enterprise Scenario Demo](4-enterprise-scenario.ipynb) for a real-world application!
