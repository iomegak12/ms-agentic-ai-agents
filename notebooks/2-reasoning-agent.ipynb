# %% [markdown]
# # Demo 2: Agent with Complex Reasoning
#
# **Semantic Kernel Agent Demo**
# *Enterprise AI Training by REDIVAC Technologies*
#
# ---
#
# ## Overview
#
# This notebook demonstrates how agents dynamically determine each next step using complex reasoning. The agent adapts based on intermediate results.
#
# **Best for:** Complex problems requiring adaptive decision-making.
#
# ---

# %% [markdown]
# ## Setup: Import Dependencies

# %%
import asyncio
import sys
from pathlib import Path

# Add parent directory to path to import modules
parent_dir = Path().resolve().parent
sys.path.insert(0, str(parent_dir))

from utils.kernel_setup import setup_kernel
from agents import demo_reasoning_agent

# %% [markdown]
# ## Initialize Semantic Kernel
#
# The kernel is initialized with:
# - Azure OpenAI connection
# - 4 plugins: MathPlugin, TextPlugin, BusinessPlugin, DataPlugin

# %%
kernel = await setup_kernel()
# Out:
# ✓ Kernel initialized with 4 plugins
#   - MathPlugin (add, multiply, subtract)
#   - TextPlugin (uppercase, count_words, reverse_text)
#   - BusinessPlugin (calculate_discount, calculate_tax, calculate_profit_margin)
#   - DataPlugin (format_currency, calculate_average, concatenate)

# %% [markdown]
# ## Run Demo: Reasoning Agent
#
# This demo includes two examples:
#
# ### Example 1: Multi-step Business Calculation with Formatting
# Apply discount, calculate tax, and format as currency.
#
# ### Example 2: Data Analysis
# Calculate average of numbers and format the result.

# %%
await demo_reasoning_agent(kernel)
# Out:
# ================================================================================
# DEMO 2: AGENT WITH COMPLEX REASONING
# ================================================================================
# The Agent dynamically determines each next step.
# It can adapt based on intermediate results.
#
# Example 1: Multi-step business calculation with formatting
# ------------------------------------------------------------
# Question: A product costs $150. Apply a 25% discount, then calculate 10% tax on the discounted price.
#     Finally, format the result as currency.
#
# Agent is working...
#
#    [BusinessPlugin] Original: $150.0, Discount: 25.0% → Final: $112.5
#    [BusinessPlugin] Price: $112.5, Tax rate: 10.0% → Tax: $11.25
#    [MathPlugin] Adding 112.5 + 11.25 = 123.75
#    [DataPlugin] Formatting currency: 123.75 → $123.75
# After applying a 25% discount to the product price of $150, the discounted price is $112.50. Adding a 10% tax results in a final price of $123.75, which is formatted as currency: **$123.75**.
#
#
# Example 2: Calculate average and format
# ------------------------------------------------------------
# Question: What is the average of these numbers: 10, 20, 30, 40, 50? Format it as currency.
#
# Agent is working...
#
#    [DataPlugin] Average of 10,20,30,40,50 = 30.0
#    [DataPlugin] Formatting currency: 30.0 → $30.00
# The average of the numbers 10, 20, 30, 40, and 50 is $30.00 when formatted as currency.

# %% [markdown]
# ## Key Takeaways
#
# ✅ **Complex reasoning** allows agents to break down problems dynamically
# ✅ **Adaptive execution** adjusts based on intermediate results
# ✅ **Step-by-step explanation** shows the agent's thought process
# ✅ **Multi-step coordination** combines multiple plugin functions seamlessly
#
# ---
#
# **Next:** Try the [Agent Comparison Demo](3-agent-comparison.ipynb) to see different agent behaviors!
